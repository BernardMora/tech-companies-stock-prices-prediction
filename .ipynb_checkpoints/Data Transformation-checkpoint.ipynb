# %% [markdown]
# # Data Transformation, Preprocessing, Cleaning and Feature Engineering

# %%
# !pip install ta
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29422 sha256=2aeb64eb11be1aaadb846a5a5f48852c21057f8a52577791ea5e872e367ecee0
#   Stored in directory: c:\users\berna\appdata\local\pip\cache\wheels\a1\d7\29\7781cc5eb9a3659d032d7d15bdd0f49d07d2b24fec29f44bc4
# Successfully built ta
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from ta import add_all_ta_features
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Define Data Transformation

# %%
def transform_data(df):
    # Add technical indicators using 'ta' library (Feature Engineering)
    df = add_all_ta_features(df, open="open", high="high", low="low", close="close", volume="volume", fillna=True)

    # Normalize the data

    # Select columns to normalize (excluding non-numeric columns like 'ticker', 'is_extended_hours', etc.)
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']
    
    # Standardization (Z-score)
#     scaler_std = StandardScaler()
#     df[columns_to_normalize] = scaler_std.fit_transform(df[columns_to_normalize])

    # Min-Max Scaling
    scaler_minmax = MinMaxScaler()
    df[columns_to_normalize] = scaler_minmax.fit_transform(df[columns_to_normalize])

    # Luis Normalization
#     close_prices_norm = np.linalg.norm(df['close'])
#     df['close'] = np.array(df['close']) / close_prices_norm

#     open_prices_norm = np.linalg.norm(df['open'])
#     df['open'] = np.array(df['open']) / open_prices_norm

#     high_prices_norm = np.linalg.norm(df['high'])
#     df['high'] = np.array(df['high']) / high_prices_norm

#     low_prices_norm = np.linalg.norm(df['low'])
#     df['low'] = np.array(df['low']) / low_prices_norm

#     volume_norm = np.linalg.norm(df['volume'])
#     df['volume'] = np.array(df['volume']) / volume_norm


    # Look for significance on 'is_extended_hours' column
    for index, row in df.iterrows():
        if row['is_extended_hours'] == True:
            print("True!") # This won't ever print
            
    # Drop because there is no significance 
    df.drop('is_extended_hours', axis=1, inplace=True)
    
    df['date'] = pd.to_datetime(df[['year', 'month', 'day', 'hour']])
    
    # Reversing the order of rows and changing the index to descending order
    df = df[::-1].reset_index(drop=True)

    
    return df

# %% [markdown]
# ### Apple

# %% [markdown]
# Transform DataFrame

# %%
# Load previously gathered data
aapl_df = pd.read_csv(r"C:\Users\berna\Documents\ML Project-CS50 Final\Finance-CompanyStocks\API Gathered Data\apple_stocks.csv")
aapl_df = transform_data(aapl_df)
aapl_df
# Out:
#      ticker      open      high       low     close    volume  year  month  \
# 0      AAPL  0.295231  0.293143  0.296532  0.293469  0.066220  2018     10
# 1      AAPL  0.290334  0.288396  0.295788  0.293693  0.090052  2018     10
# 2      AAPL  0.290285  0.288518  0.294796  0.293320  0.087171  2018     10
# 3      AAPL  0.289895  0.287417  0.295714  0.291235  0.040679  2018     10
# 4      AAPL  0.287799  0.287074  0.294771  0.291682  0.050097  2018     10
# ...     ...       ...       ...       ...       ...       ...   ...    ...
# 9789   AAPL  0.211141  0.208129  0.217407  0.214163  0.067417  2023     12
# 9790   AAPL  0.212286  0.208154  0.217011  0.213295  0.069529  2023     12
# 9791   AAPL  0.211530  0.207640  0.217234  0.213543  0.057405  2023     12
# 9792   AAPL  0.211701  0.207738  0.217135  0.213245  0.103710  2023     12
# 9793   AAPL  0.211530  0.207322  0.217928  0.213394  0.000114  2023     12
#
# ...

# %% [markdown]
# Check for missing values in the dataframe (There is none)

# %%
# Checking if any missing values exist in the DataFrame
any_missing = aapl_df.isnull().any().any()
print(f"Are there any missing values? {any_missing}")
# Out:
# Are there any missing values? False

# %%
file_path = r"C:\Users\berna\Documents\ML Project-CS50 Final\Finance-CompanyStocks\Transformed Data\apple_stocks_transformed.csv"

# Export the DataFrame to a CSV file with the specified path
aapl_df.to_csv(file_path, index=False)

# %% [markdown]
# ### Tesla

# %% [markdown]
# Transform DataFrame

# %%
tsla_df = pd.read_csv(r"C:\Users\berna\Documents\ML Project-CS50 Final\Finance-CompanyStocks\API Gathered Data\tesla_stocks.csv")
tsla_df = transform_data(tsla_df)
tsla_df
# Out:
#      ticker      open      high       low     close    volume  year  month  \
# 0      TSLA  0.073558  0.071645  0.067354  0.064777  0.025025  2018     10
# 1      TSLA  0.065797  0.066771  0.067344  0.066544  0.030929  2018     10
# 2      TSLA  0.067316  0.068729  0.067889  0.068083  0.033899  2018     10
# 3      TSLA  0.069247  0.068561  0.070177  0.067824  0.014742  2018     10
# 4      TSLA  0.068485  0.070203  0.069882  0.069755  0.028155  2018     10
# ...     ...       ...       ...       ...       ...       ...   ...    ...
# 9587   TSLA  0.060933  0.060333  0.062487  0.060612  0.025559  2023     12
# 9588   TSLA  0.061590  0.060134  0.062501  0.060008  0.016997  2023     12
# 9589   TSLA  0.060919  0.059700  0.062215  0.060576  0.023430  2023     12
# 9590   TSLA  0.061517  0.059840  0.062653  0.060671  0.046947  2023     12
# 9591   TSLA  0.061576  0.059695  0.063165  0.060626  0.000246  2023     12
#
# ...

# %% [markdown]
# Check for missing values in the dataframe (There is none)

# %%
# Checking if any missing values exist in the DataFrame
any_missing = tsla_df.isnull().any().any()
print(f"Are there any missing values? {any_missing}")
# Out:
# Are there any missing values? False

# %%
file_path = r"C:\Users\berna\Documents\ML Project-CS50 Final\Finance-CompanyStocks\Transformed Data\tesla_stocks_transformed.csv"

# Export the DataFrame to a CSV file with the specified path
tsla_df.to_csv(file_path, index=False)

# %% [markdown]
# ### Microsoft

# %% [markdown]
# Transform DataFrame

# %%
msft_df = pd.read_csv(r"C:\Users\berna\Documents\ML Project-CS50 Final\Finance-CompanyStocks\API Gathered Data\microsoft_stocks.csv")
msft_df = transform_data(msft_df)
msft_df

# %% [markdown]
# Check for missing values in the dataframe (There is none)

# %%
# Checking if any missing values exist in the DataFrame
any_missing = msft_df.isnull().any().any()
print(f"Are there any missing values? {any_missing}")

# %%
file_path = r"C:\Users\berna\Documents\ML Project-CS50 Final\Finance-CompanyStocks\Transformed Data\microsoft_stocks_transformed.csv"

# Export the DataFrame to a CSV file with the specified path
msft_df.to_csv(file_path, index=False)

# %% [markdown]
# ### Google

# %% [markdown]
# Transform DataFrame

# %%
googl_df = pd.read_csv(r"C:\Users\berna\Documents\ML Project-CS50 Final\Finance-CompanyStocks\API Gathered Data\google_stocks.csv")
googl_df = transform_data(googl_df)
googl_df

# %% [markdown]
# Check for missing values in the dataframe (There is none)

# %%
# Checking if any missing values exist in the DataFrame
any_missing = googl_df.isnull().any().any()
print(f"Are there any missing values? {any_missing}")

# %%
file_path = r"C:\Users\berna\Documents\ML Project-CS50 Final\Finance-CompanyStocks\Transformed Data\google_stocks_transformed.csv"

# Export the DataFrame to a CSV file with the specified path
googl_df.to_csv(file_path, index=False)

# %%
def graph(data, mensaje):
    plt.figure(figsize = (18,9))

    plt.plot(range(len(data['date'][:len(data['close'])])), data['close'][:len(data['close'])], label='Close Prices')

    plt.xticks(range(0,len(data['date']),500),data['date'][0::500],rotation=45)

    # (mensaje ejemplo) : Predicción de 2 redes LSTM con capa densa de salida y 20 épocas (55% train and 15% predict)
    plt.title(mensaje, fontsize=25)
    plt.xlabel('Date',fontsize=18)
    plt.ylabel('Normalized Close Prices',fontsize=18)

    plt.grid(axis = 'y', color = 'gray', linestyle = 'dashed')
    plt.legend()
    plt.show()

# %%
graph(aapl_df, 'Close Prices (Apple)')

# %%
graph(tsla_df, 'Close Prices (Tesla)')

# %%
msft_df['date'] = pd.to_datetime(msft_df[['year', 'month', 'day', 'hour']])

graph(msft_df, 'Close Prices (Microsoft)')

# %%
googl_df['date'] = pd.to_datetime(googl_df[['year', 'month', 'day', 'hour']])

graph(googl_df, 'Close Prices (Google)')
